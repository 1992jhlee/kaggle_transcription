# %% [markdown]
# ## 캐글 필사

# %% [markdown]
# - https://kaggle-kr.tistory.com/32
# ***

# %% [markdown]
# ### 1st level. Titanic: Machine Learning from Disaster
# - [타이타닉 튜토리얼 1 - Exploratory data analysis, visualization, machine learning](https://kaggle-kr.tistory.com/17?category=868316)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# #### **해야할 과정들**
# 1. 데이터셋 확인
# 2. 탐색적 데이터 분석
# 3. Feature engineering
# 4. 모델 만들기
# 5. 모델 학습 및 에측
# 6. 모델 평가

# %% [markdown]
# ***

# %% [markdown]
# #### 1. 데이터셋 확인

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - survival: 생존 여부 (0: 죽음, 1: 생존)
# - Pclass: 티켓의 클래스
# - sex: 성별
# - Age: 나이
# - sibSp: 함께 탑승한 형제와 배우자의 수
# - parch: 함께 탑승한 부모, 아이의 수
# - ticket: 티켓 번호
# - fare: 탑승료
# - cabin: 객실 번호
# - embarked: 탑승 항구

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# #### 1.1. Null data check

# %%
for col in df_train.columns:
    msg = 'column: {:>11}\t Percent of Nan Value: {:.2f}%'\
            .format(col, 100 * (df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of Nan Value: 0.00%
# column:    Survived	 Percent of Nan Value: 0.00%
# column:      Pclass	 Percent of Nan Value: 0.00%
# column:        Name	 Percent of Nan Value: 0.00%
# column:         Sex	 Percent of Nan Value: 0.00%
# column:         Age	 Percent of Nan Value: 19.87%
# column:       SibSp	 Percent of Nan Value: 0.00%
# column:       Parch	 Percent of Nan Value: 0.00%
# column:      Ticket	 Percent of Nan Value: 0.00%
# column:        Fare	 Percent of Nan Value: 0.00%
# column:       Cabin	 Percent of Nan Value: 77.10%
# column:    Embarked	 Percent of Nan Value: 0.22%

# %%
for col in df_test.columns:
    msg = 'column: {:>11}\t Percent of NaN value: {:.2f}%'\
            .format(col, 100 * (df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:      Pclass	 Percent of NaN value: 0.00%
# column:        Name	 Percent of NaN value: 0.00%
# column:         Sex	 Percent of NaN value: 0.00%
# column:         Age	 Percent of NaN value: 20.57%
# column:       SibSp	 Percent of NaN value: 0.00%
# column:       Parch	 Percent of NaN value: 0.00%
# column:      Ticket	 Percent of NaN value: 0.00%
# column:        Fare	 Percent of NaN value: 0.24%
# column:       Cabin	 Percent of NaN value: 78.23%
# column:    Embarked	 Percent of NaN value: 0.00%

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8, 8), color=(0.8, 0.5, 0.2))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 1.2. Target label 확인
# - Target label의 분포가 어떻게 되는지 확인할 필요 있음
# - 이 분포에 따라 모델 평가 방식이 달라질 수 있음

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%',
                                             ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])

plt.show()

# %% [markdown]
# 비교적 0과 1이 균일한 분포

# %% [markdown]
# #### 2. Exploratory data analysis
# - 적절한 시각화를 위한 데이터 분석 과정
# - matplotlib, seaborn, plotly 등 적절히 이용

# %% [markdown]
# #### 2.1. Pclass
# - Pclass(티켓 클래스)는 카테고리이면서, 순서가 있는 데이터 타입
# - 먼저 Pclass에 따른 생존률을 살펴 본다

# %%
df_train[['Pclass', 'Survived']].groupby('Pclass').count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby('Pclass').sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %% [markdown]
# crosstab을 이용하면 이 과정이 좀 더 쉽다.

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9c1c5_row0_col0, #T_9c1c5_row1_col1, #T_9c1c5_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9c1c5_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_9c1c5_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_9c1c5_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_9c1c5_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_9c1c5_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_9c1c5_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_9c1c5_row3_col0, #T_9c1c5_row3_col1, #T_9c1c5_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c1c5_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
# ...

# %%
df_train[['Pclass', 'Survived']].groupby('Pclass').mean().sort_values(by='Survived', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %% [markdown]
# - Pclass 1이 생존률이 높았고 3은 낮았다

# %% [markdown]
# - seaborn으로 그려 보면 아래와 같다

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position) # y = y_position을 argument로 주면 figure와 title 사이에 공간이 벌어짐
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1]) # hue의 의미: 'Pclass'를 'Survived'를 기준으로 나눠서 본다.
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# Pclass가 높을 수록 (1이 가장 높음) 생존률이 올라 가는 것을 확인할 수 있음. 따라서 feature로 사용하기 좋은 속성이라고 볼 수 있다.

# %% [markdown]
# 2.2. Sex
# - 성별에 따른 생존률 확인

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby('Sex').mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# 남자가 여자보다 월등하게 생존률이 낮았다. 역시 모델 학습 시 input feature로 사용하면 좋을 듯.

# %%
df_train[['Sex', 'Survived']].groupby('Sex').mean().sort_values(by='Survived', ascending=False)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_707fe_row0_col0, #T_707fe_row0_col2, #T_707fe_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_707fe_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_707fe_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_707fe_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_707fe_row2_col0, #T_707fe_row2_col1, #T_707fe_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_707fe_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# #### 2.3. Both Sex and Pclass
# - Sex와 Pclass 두 가지에 대해 생존이 어떻게 달라지는지 확인

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# 모든 클래스에서 남자가 여자보다 생존률이 낮고, 성별에 상관없이 클래스가 높을수록 생존률이 높음.

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
               data=df_train, satureation=.5, size=9, aspect=1)

# %% [markdown]
# #### 2.4. Age

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %% [markdown]
# - 생존에 따른 Age의 histogram

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Not survived == 0'])
plt.show()

# %% [markdown]
# 대부분의 분포가 비슷하나, 0~10세의 어린 나이가 생존한 경우가 더 많음을 확인할 수 있음.

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6))
df_train[df_train['Pclass'] == 1]['Age'].plot(kind='kde', ax=ax)
df_train[df_train['Pclass'] == 2]['Age'].plot(kind='kde', ax=ax)
df_train[df_train['Pclass'] == 3]['Age'].plot(kind='kde', ax=ax)

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])
plt.show()

# %% [markdown]
# Class가 높을 수록 나이 많은 사람의 비중이 커짐

# %% [markdown]
# - 나이대가 변하면서 생존률이 어떻게 되는지 본다.
# - 나이 범위를 점점 넓혀가며, 생존률이 어떻게 되는지 본다.

# %%
cummulate_survival_ratio = []
for i in range(1, 80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() \
                                    / len(df_train[df_train['Age'] < i]['Survived']))

fig, ax = plt.subplots(1, 1, figsize=(7, 7))
ax.plot(cummulate_survival_ratio)
ax.set_title('Survival rate change depending on range of Age', y=1.02)
ax.set_ylabel('Survival rate')
ax.set_xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# 나이가 어릴수록 생존률이 확실히 높은 것을 알 수 있음. 따라서 나이가 중요한 feature가 될 수 있음을 알 수 있다.

# %% [markdown]
# #### 2.5. Pclass, Sex, Age

# %% [markdown]
# - Seaborn의 violinplot을 이용해 Pclass, Sex, Age에 대해 한꺼번에 볼 수 있다.

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot('Pclass', 'Age', hue="Survived", data=df_train, scale='count', split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot('Sex', 'Age', hue='Survived', data=df_train, scale='count', split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# #### 2.6. Embarked
# - Embarked는 탑승한 항구를 나타냄
# - 탑승한 곳에 따른 생존률을 살펴 본다.

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby('Embarked').mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)
plt.show()

# %% [markdown]
# C에서 탄 사람이 제일 가장 생존률이 높았다. 세 클래스 간 차이가 크지는 않음.

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))
sns.countplot('Embarked', data=df_train, ax=ax[0][0])
ax[0][0].set_title('(1) No. Of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0][1])
ax[0][1].set_title('(2) Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1][0])
ax[1][0].set_title('(3) Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1][1])
ax[1][1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# (1) 전체적으로 S에서 사람이 가장 많이 탑승함
# (2) C, Q는 남녀 비율이 비슷한데 S에서는 남자 비율이 월등히 많음
# (3) S에서 탄 사람들의 생존 확률이 매우 낮았음
# (4) Pclass로 나누어서 보니, C가 생존확률이 높은 것은 클래스가 높은 사람이 많이 타서 그러함. S는 낮은 클래스 사람들이 많아서 생존확률이 낮게 나옴

# %% [markdown]
# #### 2.7. Family - SibSp(형제 자매) + Parch(부모, 자녀)
# - SibSp와 Parch를 합하면 Family가 되므로 Family로 합쳐서 분석한다.

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 본인 포함이므로 +1
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
print('Maximum size of Family: ', df_train['FamilySize'].max())
print('Minimum size of Family: ', df_test['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %% [markdown]
# - FamilySize와 생존의 관계를 본다

# %%
f, ax = plt.subplots(1, 3, figsize=(20, 15))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded')
